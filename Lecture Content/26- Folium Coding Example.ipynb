# %% [markdown]
# This Folium case study was created with contributions from previous students: Alex Du Bois, Jack Kleist, and Eric Wanner-Garnier.

# %% [markdown]
# # Folium

# %% [markdown]
# Installation: pip install folium

# %% [markdown]
# Folium is a Python library used for visualizing geospatial data. It is easy to use and yet a powerful library. Python Folium is wrapper for Leaflet.js which is a leading open-source JavaScript library for plotting interactive maps.
# It has the power of Leaflet.js and the simplicity of Python, which makes it an excellent tool for plotting maps. Folium is designed with simplicity, performance, and usability in mind. It works efficiently, can be extended with a lot of plugins, has a beautiful and easy-to-use API.
# Folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the Leaflet.js library. Manipulate your data in Python, then visualize it in a Leaflet map via Folium.

# %%
#pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.12/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from folium) (2.32.2)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.12/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2024.7.4)
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 kB 1.7 MB/s eta 0:00:00 0:00:01
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.1 folium-0.19.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
#Bozeman MT (45.6815 N, 111.0320 W)

lat = 45.6815
long = -111.0320

# %%
m = folium.Map(location = [lat, long]) # simple initialization of a map, only needs this one parameter

m # 'printing' the representation of our map object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eba8574fd78b98579da857f28d1b7d45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eba8574fd78b98579da857f28d1b7d45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eba8574fd78b98579da857f28d1b7d45 = L.map(
#                 &quot;map_eba8574fd78b98579da857f28d1b7d45&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0efadcce05aefd2219a1a42deadefe40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0efadcce05aefd2219a1a42deadefe40.addTo(map_eba8574fd78b98579da857f28d1b7d45);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#height/width
from branca.element import Figure
fig=Figure(width=550,height=350)
m = folium.Map(location = [lat, long], width=550,height=350) 
# if you send in numbers, it is interpreted as integers.  if you switch it to a string with '%' at the end, it is percentage of it's div
fig.add_child(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_336e04ba019b7899248cbf1aa09bb9ee {
#                     position: relative;
#                     width: 550.0px;
#                     height: 350.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_336e04ba019b7899248cbf1aa09bb9ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_336e04ba019b7899248cbf1aa09bb9ee = L.map(
#                 &quot;map_336e04ba019b7899248cbf1aa09bb9ee&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_077c5159d9e488f2624da75f466beb82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_077c5159d9e488f2624da75f466beb82.addTo(map_336e04ba019b7899248cbf1aa09bb9ee);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="550" height="350"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
#fit bounds

m = folium.Map(location=[lat, long], width=550,height=350)

folium.FitBounds(
    bounds= [[lat-1, long-1], [lat+1, long+1]] # sw, ne corners 
).add_to(m)
# this behaves similarly to zoom_start, but is probably easier to impliment if you're able to extract the range of data you're trying to display in one view.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68c3b51efbc2e21c3b5bcf37d4c5efe1 {
#                     position: relative;
#                     width: 550.0px;
#                     height: 350.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68c3b51efbc2e21c3b5bcf37d4c5efe1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68c3b51efbc2e21c3b5bcf37d4c5efe1 = L.map(
#                 &quot;map_68c3b51efbc2e21c3b5bcf37d4c5efe1&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31747055db7ec108267f5a4f2281739f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31747055db7ec108267f5a4f2281739f.addTo(map_68c3b51efbc2e21c3b5bcf37d4c5efe1);
#
#
#             map_68c3b51efbc2e21c3b5bcf37d4c5efe1.fitBounds(
#                 [[44.6815, -112.032], [46.6815, -110.032]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# A tileset is a collection of raster and vector data broken up into a uniform grid of square tiles. Each tileset has a different way of representing data in the map. Folium allows us to create maps with different tiles like Stamen Terrain, Stamen Toner, Stamen Water Color, CartoDB Positron, and many more. By default, the tiles are set to OpenStreetMap.
#
# Each tileset shows different features of a map and is suitable for different purposes. For example, Stamen Terrain features hill shading and natural vegetation colors. It showcases advanced labeling and linework generalization of dual-carriageway roads. And, CartoDB Dark Matter shows the CartoDB Positron map in dark mode.

# %%
#tiles

#m = folium.Map(location = [lat, long], tiles='OpenStreetMap', width=1000,height=500) # default
#m = folium.Map(location= [lat, long], tiles= 'Esri.WorldTerrain', width=1000,height=500)
m = folium.Map(location= [lat, long], tiles= 'OpenTopoMap', width=1000,height=500)

## tile sets: http://leaflet-extras.github.io/leaflet-providers/preview/  Large collection of tile sets, free for use with attribution or without with a subscription
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf530f62c50f3f1babc797689c4bf3e6 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf530f62c50f3f1babc797689c4bf3e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf530f62c50f3f1babc797689c4bf3e6 = L.map(
#                 &quot;map_cf530f62c50f3f1babc797689c4bf3e6&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0c050fa99875299da6dad333002ebc2 = L.tileLayer(
#                 &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 17,
#   &quot;maxNativeZoom&quot;: 17,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u003ca href=\&quot;http://viewfinderpanoramas.org\&quot;\u003eSRTM\u003c/a\u003e | Map style: \u0026copy; \u003ca href=\&quot;https://opentopomap.org\&quot;\u003eOpenTopoMap\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0c050fa99875299da6dad333002ebc2.addTo(map_cf530f62c50f3f1babc797689c4bf3e6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location = [lat, long] , zoom_start=7, min_zoom=6 , max_zoom=10) 
folium.TileLayer('OpenStreetMap').add_to(m)
folium.TileLayer('StamenTerrain').add_to(m)
folium.TileLayer('Stamen Toner').add_to(m)
folium.TileLayer('Stamen Water Color').add_to(m)
folium.TileLayer('cartodbpositron').add_to(m)
folium.TileLayer('cartodbdark_matter').add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbcc7ad6ca6736608257afa7cd030317 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbcc7ad6ca6736608257afa7cd030317&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbcc7ad6ca6736608257afa7cd030317 = L.map(
#                 &quot;map_fbcc7ad6ca6736608257afa7cd030317&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef3bbd730fa756dcd6f98614f93618b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 6,
#   &quot;maxZoom&quot;: 10,
#   &quot;maxNativeZoom&quot;: 10,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef3bbd730fa756dcd6f98614f93618b8.addTo(map_fbcc7ad6ca6736608257afa7cd030317);
#
#
#             var tile_layer_7d1caf2a00f2e7e3b6ad184fa679f045 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d1caf2a00f2e7e3b6ad184fa679f045.addTo(map_fbcc7ad6ca6736608257afa7cd030317);
#
#
#             var tile_layer_45810dff2779fb3f92c8ce6e8c3bdc04 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45810dff2779fb3f92c8ce6e8c3bdc04.addTo(map_fbcc7ad6ca6736608257afa7cd030317);
#
#
#             var tile_layer_79daf7449994c9645860c5ae3a335e95 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {
#   &quot;minZoom&quot;: 1,
#   &quot;maxZoom&quot;: 16,
#   &quot;maxNativeZoom&quot;: 16,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79daf7449994c9645860c5ae3a335e95.addTo(map_fbcc7ad6ca6736608257afa7cd030317);
#
#
#             var tile_layer_ab5a8dce821a9e0752534c44c7b40f82 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab5a8dce821a9e0752534c44c7b40f82.addTo(map_fbcc7ad6ca6736608257afa7cd030317);
#
#
#             var tile_layer_f50aac8056dcd01f49a342683235943c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/c

# %%
#Simple Shapes
m = folium.Map(location= [lat, long])

folium.CircleMarker(
    location=[lat, long],
    radius = 10
).add_to(m)

folium.RegularPolygonMarker(
    location=[lat, long],
    number_of_sides=4,
    radius=150,
    fill_color = 'red'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_371640c6c730922c899b7f2707cb77ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_371640c6c730922c899b7f2707cb77ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_371640c6c730922c899b7f2707cb77ea = L.map(
#                 &quot;map_371640c6c730922c899b7f2707cb77ea&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_761555a7d65247938e3851aef9b98fe3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_761555a7d65247938e3851aef9b98fe3.addTo(map_371640c6c730922c899b7f2707cb77ea);
#
#
#             var circle_marker_6af67edcbd904264ccaa8b57a0ae2253 = L.circleMarker(
#                 [45.6815, -111.032],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_371640c6c730922c899b7f2707cb77ea);
#
#
#             var regular_polygon_marker_21c96b8e5a6eeec15ec5a06508cb1c53 = new L.RegularPolygonMarker(
#                 [45.6815, -111.032],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 150,
#   &quot;numberOfSides&quot;: 4,
#   &quot;rotation&quot;: 0,
# }
#             ).addTo(map_371640c6c730922c899b7f2707cb77ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The text when you hover over a marker is known as tooltip and the content when you click on a marker is known as a popup.

# %%
#markers
m = folium.Map(location=[45.372, -121.6972], zoom_start=12, min_zoom=10)

tooltip = "Click me!"

#standard formatting.  There are extra visualization options for this in the documentation
#you can even completely overwrite the 'marker' with an image, local or via url
folium.Marker(
    [45.3288, -121.6625], 
    popup="<i>Mt. Hood Meadows</i>",
    tooltip=tooltip
).add_to(m)

folium.Marker(
    [45.3311, -121.7113], 
    popup="<b>Timberline Lodge</b>", 
    tooltip=tooltip
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56c5f27606d54c2a4c25d4f4db80473f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56c5f27606d54c2a4c25d4f4db80473f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56c5f27606d54c2a4c25d4f4db80473f = L.map(
#                 &quot;map_56c5f27606d54c2a4c25d4f4db80473f&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74659c94f5f9ef2f5e86531cb2aa5d43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 10,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74659c94f5f9ef2f5e86531cb2aa5d43.addTo(map_56c5f27606d54c2a4c25d4f4db80473f);
#
#
#             var marker_cd3c246f35929a96693a861f7215dbe4 = L.marker(
#                 [45.3288, -121.6625],
#                 {
# }
#             ).addTo(map_56c5f27606d54c2a4c25d4f4db80473f);
#
#
#         var popup_8b27cfa79c9eaaa9202be53de82a99d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_718a31c838c427733c572b7663c23c55 = $(`&lt;div id=&quot;html_718a31c838c427733c572b7663c23c55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_8b27cfa79c9eaaa9202be53de82a99d0.setContent(html_718a31c838c427733c572b7663c23c55);
#
#
#
#         marker_cd3c246f35929a96693a861f7215dbe4.bindPopup(popup_8b27cfa79c9eaaa9202be53de82a99d0)
#         ;
#
#
#
#
#             marker_cd3c246f35929a96693a861f7215dbe4.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_18fd4e122bdbb73a5bf79eb7951d7bfe = L.marker(
#                 [45.3311, -121.7113],
#                 {
# }
#             ).addTo(map_56c5f27606d54c2a4c25d4f4db80473f);
#
#
#         var popup_12c2ae437499ceadf36c8cada4a921da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e00f0d1bcb6ec87216e0e3f59f0482c3 = $(`&lt;div id=&quot;html_e00f0d1bcb6ec87216e0e3f59f0482c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Timberline Lodge&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_12c2ae437499ceadf36c8cada4a921da.setContent(html_e00f0d1bcb6ec87216e0e3f59f0482c3);
#
#
#
#         marker_18fd4e122bdbb73a5bf79eb7951d7bfe.bindPopup(popup_12c2ae437499ceadf36c8cada4a921da)
#         ;
#
#
#
#
#             marker_18fd4e122bdbb73a5bf79eb7951d7bfe.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[45.372, -121.6972], zoom_start=12)

#simple interactable markers
m.add_child(folium.ClickForMarker(popup="Waypoint"))

#you can save the whole map object in it's HTML representation.  When opened, it still has all of its attributes and interactability.
m.save("demo.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0188658d1d7ff5f0732871402bc11c3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0188658d1d7ff5f0732871402bc11c3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0188658d1d7ff5f0732871402bc11c3f = L.map(
#                 &quot;map_0188658d1d7ff5f0732871402bc11c3f&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c654bb7d20cf239f4c0665f6ff34d3e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c654bb7d20cf239f4c0665f6ff34d3e7.addTo(map_0188658d1d7ff5f0732871402bc11c3f);
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_0188658d1d7ff5f0732871402bc11c3f);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_0188658d1d7ff5f0732871402bc11c3f.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`Waypoint`);
#                     };
#                 map_0188658d1d7ff5f0732871402bc11c3f.on(&#x27;click&#x27;, newMarker);
#
#
#             tile_layer_c654bb7d20cf239f4c0665f6ff34d3e7.addTo(map_0188658d1d7ff5f0732871402bc11c3f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Mapping the Avalanche Accidents Dataset

# %% [markdown]
# The below code drops the NA values, converts the lat, lon, and people killed to numbers, as well as replaces mistyped data with correctly typed data

# %%
import pandas as pd
avalanche_df = pd.read_csv("Avalanche_Accidents_2022_PUBLIC.csv")
avalanche_cleaned_df = avalanche_df.dropna()
avalanche_cleaned_df = avalanche_cleaned_df.set_index('Date')

# %%
avalanche_cleaned_df['lat'] = pd.to_numeric(avalanche_cleaned_df['lat'])
avalanche_cleaned_df['lon'] = pd.to_numeric(avalanche_cleaned_df['lon'])
avalanche_cleaned_df['Killed'] = pd.to_numeric(avalanche_cleaned_df['Killed'])

# %%
avalanche_cleaned_df
# Out:
#             AvyYear  YYYY  MM  DD  \
# Date
# 5/29/2022      2022  2022   5  29
# 4/25/2022      2022  2022   4  25
# 3/19/2022      2022  2022   3  19
# 3/17/2022      2022  2022   3  17
# 3/17/2022      2022  2022   3  17
# ...             ...   ...  ..  ..
# 1/21/2019      2019  2019   1  21
# 1/9/2019       2019  2019   1   9
# 1/5/2019       2019  2019   1   5
# 1/5/2019       2019  2019   1   5
# 12/22/2018     2019  2018  12  22
#
#                                                      Location Trigger  D Size  \
# Date
# 5/29/2022          Mount Meeker, Rocky Mountain National Park       N     3.0
# 4/25/2022   Ice Face, southeast of Thompson Pass, Chugach ...      AS     2.0
# 3/19/2022    North Fork of Fish Creek, near Steamboat Springs      AS     2.0
# 3/17/2022                Pilot Knob, east of Lizard Head Pass      AR     2.5
# 3/17/2022           Game Creek Drainage, east of Victor Idaho      AS     2.5
# ...                                                       ...     ...     ...
# 1/21/2019                       Green Mountain, Express Creek      AS     2.5
# 1/9/2019              Mount Leidy, southwest of Togwotee Pass      AM     2.0
# 1/5/2019    Upper Senator Beck Basin, northwest of Red Mou...      AS     2.0
# 1/5/2019             South Waldron Creek, north of Teton Peak      AM     3.0
# 12/22/2018                         Horse Creek, Wyoming Range      AM     1.5
#
#            Setting State        lat         lon     PrimaryActivity  \
# Date
# 5/29/2022       BC    CO  40.253370 -105.600944             Climber
# 4/25/2022       BC    AK  61.126299 -145.727162    Mechanised Guide
# 3/19/2022       BC    CO  40.505660 -106.720470  Backcountry Tourer
# 3/17/2022       BC    CO  37.811000 -107.838000  Backcountry Tourer
# 3/17/2022       BC    WY  43.594646 -111.011139  Backcountry Tourer
# ...            ...   ...        ...         ...                 ...
# 1/21/2019       BC    CO  39.025500 -106.785110  Backcountry Tourer
# 1/9/2019        BC    WY  43.724310 -110.405040         Snowmobiler
# 1/5/2019        BC    CO  37.914670 -107.733620  Backcountry Tourer
# 1/5/2019        BC    MT  47.925500 -112.795380         Snowmobiler
# 12/22/2018      BC    WY  42.928524 -110.525528         Snowmobiler
#
#             TravelMode  Killed  \
# Date
# 5/29/2022         Foot       1
# 4/25/2022          Ski       1
# 3/19/2022          Ski       1
# 3/17/2022    Snowboard       1
# 3/17/2022          Ski       1
# ...                ...     ...
# 1/21/2019          Ski       1
# 1/9/2019    Snowmobile       1
# 1/5/2019           Ski       1
# 1/5/2019    Snowmobile       1
# 12/22/2018  Snowmobile       1
#
#                                                   Description
# Date
# 5/29/2022   3 climbers caught, 1 partially buried, 1 injur...
# 4/25/2022      1 skier caught, carried over cliff, and killed
# 3/19/2022   1 backcountry skier caught, partially buried-c...
# 3/17/2022   1 backcountry snowboarder caught, buried, and ...
# 3/17/2022   2 skiers caught, 2 fully buried, 1 injured, an...
# ...                                                       ...
# 1/21/2019     1 backcountry tourer caught, buried, and killed
# 1/9/2019             1 snowmobiler caught, buried, and killed
# 1/5/2019    6 backcountry tourers caught, 1 partially buri...
# 1/5/2019    2 snowmobilers caught, 1 carried and injured, ...
# 12/22/2018           1 snowmobiler caught, buried, and killed
#
# [68 rows x 15 columns]

# %%
#This is finding the average lat and lon of all the points in order to decide where to start the map
avg_lat = avalanche_cleaned_df.loc[:,'lat'].mean(axis=0)
avg_lon = avalanche_cleaned_df.loc[:,'lon'].mean(axis=0)

# %%
avalanche_cleaned_df
# Out:
#             AvyYear  YYYY  MM  DD  \
# Date
# 5/29/2022      2022  2022   5  29
# 4/25/2022      2022  2022   4  25
# 3/19/2022      2022  2022   3  19
# 3/17/2022      2022  2022   3  17
# 3/17/2022      2022  2022   3  17
# ...             ...   ...  ..  ..
# 1/21/2019      2019  2019   1  21
# 1/9/2019       2019  2019   1   9
# 1/5/2019       2019  2019   1   5
# 1/5/2019       2019  2019   1   5
# 12/22/2018     2019  2018  12  22
#
#                                                      Location Trigger  D Size  \
# Date
# 5/29/2022          Mount Meeker, Rocky Mountain National Park       N     3.0
# 4/25/2022   Ice Face, southeast of Thompson Pass, Chugach ...      AS     2.0
# 3/19/2022    North Fork of Fish Creek, near Steamboat Springs      AS     2.0
# 3/17/2022                Pilot Knob, east of Lizard Head Pass      AR     2.5
# 3/17/2022           Game Creek Drainage, east of Victor Idaho      AS     2.5
# ...                                                       ...     ...     ...
# 1/21/2019                       Green Mountain, Express Creek      AS     2.5
# 1/9/2019              Mount Leidy, southwest of Togwotee Pass      AM     2.0
# 1/5/2019    Upper Senator Beck Basin, northwest of Red Mou...      AS     2.0
# 1/5/2019             South Waldron Creek, north of Teton Peak      AM     3.0
# 12/22/2018                         Horse Creek, Wyoming Range      AM     1.5
#
#            Setting State        lat         lon     PrimaryActivity  \
# Date
# 5/29/2022       BC    CO  40.253370 -105.600944             Climber
# 4/25/2022       BC    AK  61.126299 -145.727162    Mechanised Guide
# 3/19/2022       BC    CO  40.505660 -106.720470  Backcountry Tourer
# 3/17/2022       BC    CO  37.811000 -107.838000  Backcountry Tourer
# 3/17/2022       BC    WY  43.594646 -111.011139  Backcountry Tourer
# ...            ...   ...        ...         ...                 ...
# 1/21/2019       BC    CO  39.025500 -106.785110  Backcountry Tourer
# 1/9/2019        BC    WY  43.724310 -110.405040         Snowmobiler
# 1/5/2019        BC    CO  37.914670 -107.733620  Backcountry Tourer
# 1/5/2019        BC    MT  47.925500 -112.795380         Snowmobiler
# 12/22/2018      BC    WY  42.928524 -110.525528         Snowmobiler
#
#             TravelMode  Killed  \
# Date
# 5/29/2022         Foot       1
# 4/25/2022          Ski       1
# 3/19/2022          Ski       1
# 3/17/2022    Snowboard       1
# 3/17/2022          Ski       1
# ...                ...     ...
# 1/21/2019          Ski       1
# 1/9/2019    Snowmobile       1
# 1/5/2019           Ski       1
# 1/5/2019    Snowmobile       1
# 12/22/2018  Snowmobile       1
#
#                                                   Description
# Date
# 5/29/2022   3 climbers caught, 1 partially buried, 1 injur...
# 4/25/2022      1 skier caught, carried over cliff, and killed
# 3/19/2022   1 backcountry skier caught, partially buried-c...
# 3/17/2022   1 backcountry snowboarder caught, buried, and ...
# 3/17/2022   2 skiers caught, 2 fully buried, 1 injured, an...
# ...                                                       ...
# 1/21/2019     1 backcountry tourer caught, buried, and killed
# 1/9/2019             1 snowmobiler caught, buried, and killed
# 1/5/2019    6 backcountry tourers caught, 1 partially buri...
# 1/5/2019    2 snowmobilers caught, 1 carried and injured, ...
# 12/22/2018           1 snowmobiler caught, buried, and killed
#
# [68 rows x 15 columns]

# %%
#this declares the folium map and where it's located

basic_map=folium.Map(location=[avg_lat,avg_lon],zoom_start=4)
for index,row in avalanche_cleaned_df.iterrows():
    folium.Marker(location=[row['lat'],row['lon']], popup=[row['State'], row['Killed']], tooltip='More Info').add_to(basic_map)

# %%
basic_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f8c30e03552f4314c08beb2a621d999 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f8c30e03552f4314c08beb2a621d999&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f8c30e03552f4314c08beb2a621d999 = L.map(
#                 &quot;map_1f8c30e03552f4314c08beb2a621d999&quot;,
#                 {
#                     center: [42.79134132647059, -111.34366468235295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a84eec20afa1effcf4954a056a54cb98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a84eec20afa1effcf4954a056a54cb98.addTo(map_1f8c30e03552f4314c08beb2a621d999);
#
#
#             var marker_2c6cfe437c28f14daccd773808456306 = L.marker(
#                 [40.25337, -105.600944],
#                 {
# }
#             ).addTo(map_1f8c30e03552f4314c08beb2a621d999);
#
#
#         var popup_3719e0e54df1432fa9efc54a1926eaa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e089892a7c6d45275f76c1a5c864d662 = $(`&lt;div id=&quot;html_e089892a7c6d45275f76c1a5c864d662&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CO&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_3719e0e54df1432fa9efc54a1926eaa0.setContent(html_e089892a7c6d45275f76c1a5c864d662);
#
#
#
#         marker_2c6cfe437c28f14daccd773808456306.bindPopup(popup_3719e0e54df1432fa9efc54a1926eaa0)
#         ;
#
#
#
#
#             marker_2c6cfe437c28f14daccd773808456306.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_d564cce47d3bbf73935ba02412f660e9 = L.marker(
#                 [61.1262988, -145.7271624],
#                 {
# }
#             ).addTo(map_1f8c30e03552f4314c08beb2a621d999);
#
#
#         var popup_2374c60b7f68aa1ba6473005a9988478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_855d6026eed5967c2016f5e85e5377b6 = $(`&lt;div id=&quot;html_855d6026eed5967c2016f5e85e5377b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;AK&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_2374c60b7f68aa1ba6473005a9988478.setContent(html_855d6026eed5967c2016f5e85e5377b6);
#
#
#
#         marker_d564cce47d3bbf73935ba02412f660e9.bindPopup(popup_2374c60b7f68aa1ba6473005a9988478)
#         ;
#
#
#
#
#             marker_d564cce47d3bbf73935ba02412f660e9.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_44e98d195e93889c2082b2aaaaca190c = L.marker(
#                 [40.50566, -106.72047],
#                 {
# }
#             ).addTo(map_1f8c30e03552f4314c08beb2a621d999);
#
#
#         var popup_8632ac6e92711b559d9e73784294fbda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4017f1d85bccf4ff8fcbf68bcd7680d1 = $(`&lt;div id=&quot;html_4017f1d85bccf4ff8fcbf68bcd7680d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CO&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_8632ac6e92711b559d9e73784294fbda.setContent(html_4017f1d85bccf4ff8fcbf68bcd7680d1);
#
#
#
#         marker_44e98d195e93889c2082b2aaaaca190c.bindPopup(popup_8632ac6e92711b559d9e73784294fbda)
#         ;
#
#
#
#
#             marker_44e98d195e93889c2082b2aaaaca190c.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0c0603219c7a0c9e892a9efa2f50ec83 = L.marker(
#                 [37.811, -107.838],
#                 {
# }
#             ).addTo(map_1f8c30e03552f4314c08beb2a621d999);
#
#
#         var popup_07591fb75ff1d619355f3b304d971be6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f744fcc9d64503999a64ac2005255403 = $(`&lt;div id=&quot;html_f744fcc9d64503999a64ac2005255403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CO&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_07591fb75ff1d619355f3b304d971be6.setContent(html_f744fcc9d64503999a64ac2005255403);
#
#
#
#         marker_0c0603219c7a0c9e892a9efa2f50ec83.bindPopup(popup_07591fb75ff1d619355f3b304d971be6)
#         ;
#
#
#
#
#             marker_0c0603219c7a0c9e892a9efa2f50ec83.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {

# %% [markdown]
# # Creatingn a Choropleth

# %%
#pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in /opt/anaconda3/lib/python3.12/site-packages (from geopandas) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from geopandas) (2.2.2)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading pyogrio-0.10.0-cp312-cp312-macosx_12_0_arm64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 30.7 MB/s eta 0:00:0000:0100:01
# Downloading pyproj-3.7.1-cp312-cp312-macosx_14_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 26.0 MB/s eta 0:00:00a 0:00:01
# Downloading shapely-2.1.0-cp312-cp312-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.1 shapely-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import geopandas
from folium.plugins import TimeSliderChoropleth
url = ("https://raw.githubusercontent.com/python-visualization/folium/main/examples/data")

# %%
# Select the columns of our dataset that we need, and convert the year column to a date value
avalanche_df = pd.read_csv('Avalanche_Accidents_2022_PUBLIC.csv')
avalanche_cleaned_df = avalanche_df[["AvyYear","State","Killed"]]
avalanche_cleaned_df['AvyYear'] = pd.to_datetime(avalanche_cleaned_df['AvyYear'],format='%Y')

avalanche_cleaned_df['AvyYear']
# Out:
# /var/folders/_x/n_g0v4195t34h6v_rhvdzwww0000gq/T/ipykernel_14319/1698734307.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avalanche_cleaned_df['AvyYear'] = pd.to_datetime(avalanche_cleaned_df['AvyYear'],format='%Y')
# 0     2022-01-01
# 1     2022-01-01
# 2     2022-01-01
# 3     2022-01-01
# 4     2022-01-01
#          ...
# 951   1952-01-01
# 952   1952-01-01
# 953   1952-01-01
# 954   1952-01-01
# 955   1951-01-01
# Name: AvyYear, Length: 956, dtype: datetime64[ns]

# %%
avalanche_df.head()
# Out:
#    AvyYear  YYYY  MM  DD                                           Location  \
# 0     2022  2022   5  29         Mount Meeker, Rocky Mountain National Park
# 1     2022  2022   4  25  Ice Face, southeast of Thompson Pass, Chugach ...
# 2     2022  2022   3  19   North Fork of Fish Creek, near Steamboat Springs
# 3     2022  2022   3  17               Pilot Knob, east of Lizard Head Pass
# 4     2022  2022   3  17          Game Creek Drainage, east of Victor Idaho
#
#   Trigger  D Size Setting State         lat           lon     PrimaryActivity  \
# 0       N     3.0      BC    CO    40.25337   -105.600944             Climber
# 1      AS     2.0      BC    AK  61.1262988  -145.7271624    Mechanised Guide
# 2      AS     2.0      BC    CO    40.50566    -106.72047  Backcountry Tourer
# 3      AR     2.5      BC    CO      37.811      -107.838  Backcountry Tourer
# 4      AS     2.5      BC    WY   43.594646   -111.011139  Backcountry Tourer
#
#   TravelMode  Killed                                        Description  \
# 0       Foot       1  3 climbers caught, 1 partially buried, 1 injur...
# 1        Ski       1     1 skier caught, carried over cliff, and killed
# 2        Ski       1  1 backcountry skier caught, partially buried-c...
# 3  Snowboard       1  1 backcountry snowboarder caught, buried, and ...
# 4        Ski       1  2 skiers caught, 2 fully buried, 1 injured, an...
#
#         Date
# 0  5/29/2022
# 1  4/25/2022
# 2  3/19/2022
# 3  3/17/2022
# 4  3/17/2022

# %%
# Reformat date column to U10, as that is the format the choropleth function expects
avalanche_cleaned_df['AvyYear']=(avalanche_cleaned_df['AvyYear'].astype(int)//10**9).astype("U10")
avalanche_cleaned_df['AvyYear']
# Out:
# /var/folders/_x/n_g0v4195t34h6v_rhvdzwww0000gq/T/ipykernel_14319/142718763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avalanche_cleaned_df['AvyYear']=(avalanche_cleaned_df['AvyYear'].astype(int)//10**9).astype("U10")
# 0      1640995200
# 1      1640995200
# 2      1640995200
# 3      1640995200
# 4      1640995200
#           ...
# 951    -568080000
# 952    -568080000
# 953    -568080000
# 954    -568080000
# 955    -599616000
# Name: AvyYear, Length: 956, dtype: object

# %%
# Group the data by state and year
grouped_avy_df = avalanche_cleaned_df.groupby(["AvyYear","State"])["Killed"].sum()
new_grouped_avy_df = grouped_avy_df.reset_index()
bins=np.linspace(min(new_grouped_avy_df['Killed']),max(new_grouped_avy_df['Killed']),12)
bins

new_grouped_avy_df.head()
# Out:
#       AvyYear State  Killed
# 0  -126230400    CO       1
# 1  -126230400    UT       1
# 2  -126230400    WA       1
# 3  -157766400    CA       1
# 4  -157766400    CO       2

# %%
# Create color data for each data point for display on our map 
from branca.colormap import linear

cmap = linear.BuPu_06.scale(1, 12)

killedSeries = pd.Series(new_grouped_avy_df["Killed"], copy=False)
killedSeries = killedSeries.apply(cmap)
new_grouped_avy_df["Color"] = killedSeries

new_grouped_avy_df.head()
# Out:
#       AvyYear State  Killed      Color
# 0  -126230400    CO       1  #edf8fbff
# 1  -126230400    UT       1  #edf8fbff
# 2  -126230400    WA       1  #edf8fbff
# 3  -157766400    CA       1  #edf8fbff
# 4  -157766400    CO       2  #d8e8f2ff

# %%
# Gather geography data for each state
state_geo = geopandas.read_file(f"{url}/us-states.json")

state_geo.head()
# Out:
#    id        name                                           geometry
# 0  AL     Alabama  POLYGON ((-87.3593 35.00118, -85.60668 34.9847...
# 1  AK      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2  AZ     Arizona  POLYGON ((-109.0425 37.00026, -109.04798 31.33...
# 3  AR    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  CA  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...

# %%
# Create style dictionary for the map - associating each state location with a number of deaths & color
avy_dict={}

for state in new_grouped_avy_df['State'].unique():
    avy_dict[state] = {}
    for j in new_grouped_avy_df[new_grouped_avy_df["State"]==state].set_index('State').values:
        avy_dict[state][j[0]]={'color':j[2],'opacity':.8}

# %%
# Create choropleth - create map and then add a time slider and a legend
m = folium.Map(location=[48,-102],height=850,width=1000, zoom_start=3, max_zoom=6, min_zoom=4)

folium.TileLayer('Stamen Terrain').add_to(m)

TimeSliderChoropleth(
    state_geo.set_index('id').to_json(),
    styledict=avy_dict
).add_to(m)

folium.Choropleth(
    geo_data=state_geo.set_index('id').to_json(),
    data=new_grouped_avy_df,
    columns=['AvyYear', 'Killed'],
    key_on='feature.id',
    fill_color= 'BuPu',
    fill_opacity=0.0,
    line_opacity=0.0,
    legend_name='Deaths'
).add_to(m)

# %%
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7073adda876c79e1bdb6dd2d3cc00be5 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 850.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://d3js.org/d3.v4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7073adda876c79e1bdb6dd2d3cc00be5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7073adda876c79e1bdb6dd2d3cc00be5 = L.map(
#                 &quot;map_7073adda876c79e1bdb6dd2d3cc00be5&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cc3dddd1abf54c6580aa7ed302eca49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 4,
#   &quot;maxZoom&quot;: 6,
#   &quot;maxNativeZoom&quot;: 6,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cc3dddd1abf54c6580aa7ed302eca49.addTo(map_7073adda876c79e1bdb6dd2d3cc00be5);
#
#
#             var tile_layer_0423823d23c1149f63a05a541a183446 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0423823d23c1149f63a05a541a183446.addTo(map_7073adda876c79e1bdb6dd2d3cc00be5);
#
#
#         {
#             let timestamps = [&quot;-599616000&quot;, &quot;-568080000&quot;, &quot;-536457600&quot;, &quot;-504921600&quot;, &quot;-473385600&quot;, &quot;-441849600&quot;, &quot;-410227200&quot;, &quot;-378691200&quot;, &quot;-347155200&quot;, &quot;-315619200&quot;, &quot;-283996800&quot;, &quot;-252460800&quot;, &quot;-220924800&quot;, &quot;-189388800&quot;, &quot;-157766400&quot;, &quot;-126230400&quot;, &quot;-94694400&quot;, &quot;-63158400&quot;, &quot;-31536000&quot;, &quot;0&quot;, &quot;31536000&quot;, &quot;63072000&quot;, &quot;94694400&quot;, &quot;126230400&quot;, &quot;157766400&quot;, &quot;189302400&quot;, &quot;220924800&quot;, &quot;252460800&quot;, &quot;283996800&quot;, &quot;315532800&quot;, &quot;347155200&quot;, &quot;378691200&quot;, &quot;410227200&quot;, &quot;441763200&quot;, &quot;473385600&quot;, &quot;504921600&quot;, &quot;536457600&quot;, &quot;567993600&quot;, &quot;599616000&quot;, &quot;631152000&quot;, &quot;662688000&quot;, &quot;694224000&quot;, &quot;725846400&quot;, &quot;757382400&quot;, &quot;788918400&quot;, &quot;820454400&quot;, &quot;852076800&quot;, &quot;883612800&quot;, &quot;915148800&quot;, &quot;946684800&quot;, &quot;978307200&quot;, &quot;1009843200&quot;, &quot;1041379200&quot;, &quot;1072915200&quot;, &quot;1104537600&quot;, &quot;1136073600&quot;, &quot;1167609600&quot;, &quot;1199145600&quot;, &quot;1230768000&quot;, &quot;1262304000&quot;, &quot;1293840000&quot;, &quot;1325376000&quot;, &quot;1356998400&quot;, &quot;1388534400&quot;, &quot;1420070400&quot;, &quot;1451606400&quot;, &quot;1483228800&quot;, &quot;1514764800&quot;, &quot;1546300800&quot;, &quot;1577836800&quot;, &quot;1609459200&quot;, &quot;1640995200&quot;];
#             let styledict = {&quot;AK&quot;: {&quot;-504921600&quot;: {&quot;color&quot;: &quot;#d8e8f2ff&quot;, &quot;opacity&quot;: 0.8}, &quot;-568080000&quot;: {&quot;color&quot;: &quot;#edf8fbff&quot;, &quot;opacity&quot;: 0.8}, &quot;1009843200&quot;: {&quot;color&quot;: &quot;#842f90ff&quot;, &quot;opacity&quot;: 0.8}, &quot;1041379200&quot;: {&quot;color&quot;: &quot;#b3cbe2ff&quot;, &quot;opacity&quot;: 0.8}, &quot;1072915200&quot;: {&quot;color&quot;: &quot;#c3d7e8ff&quot;, &quot;opacity&quot;: 0.8}, &quot;1104537600&quot;: {&quot;color&quot;: &quot;#edf8fbff&quot;, &quot;opacity&quot;: 0.8}, &quot;1136073600&quot;: {&quot;color&quot;: &quot;#b3cbe2ff&quot;, &quot;opacity&quot;: 0.8}, &quot;1199145600&quot;: {&quot;color&quot;: &quot;#b3cbe2ff&quot;, &quot;opacity&quot;: 0.8}, &quot;1230768000&quot;: {&quot;color&quot;: &quot;#d8e8f2ff&quot;, &quot;opacity&quot;: 0.8}, &quot;126230400&quot;: {&quot;color&quot;: &quot;#c3d7e8ff&quot;, &quot;opacity&quot;: 0.8}, &quot;1262304000&quot;: {&quot;color&quot;: &quot;#a4c0ddff&quot;, &quot;opacity&quot;: 0.8}, &quot;1293840000&quot;: {&quot;color&quot;: &quot
